# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Edunet Foundation : Class Room Exercises

# %% [markdown]
# # Lab 17 Edge Detection with OpenCV​
#
# ### Objective:
#
# The objective of the "Edge Detection with OpenCV" lab is to equip learners with the skills to identify and analyze edges in images using the OpenCV library in Python. The lab begins with an introduction to the importance of edge detection in image processing and computer vision. Learners will gain hands-on experience in applying various edge detection techniques, such as the Sobel, and Canny, to identify edges in images. The lab will cover the concepts behind each technique, as well as the implementation and parameter tuning using OpenCV functions. By the end of the lab, learners will be proficient in detecting edges to enhance image analysis and processing tasks, enabling them to apply these techniques in real-world computer vision applications.

# %%
# !pip install opencv-python

# %% [markdown]
# ## Import Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image

# %%
print("OpenCV-Python Version %s" % cv2.__version__)
# Out:
# OpenCV-Python Version 4.8.0

# %% [markdown]
# # What is Edge Detection?
# As we know, the computer sees the images in the form of matrices. As shown here.
#
# ![88.png](data:image/png;base64,...)
#
#
# In this case, we can clearly identify the edges by looking at the numbers or the pixel values. So if you look closely in the matrix of the numbers, there is a significant difference between the pixel values around the edge. The black area in the left image is represented by low values as shown in the second image. Similarly, the white area is represented by the larger numbers.
#
# Edge detection is an image processing technique for finding the boundaries of an object in the given image.
#
# ---
# Whereas, if you look at the pixels in the following image. The pixel values to the left and the right of the selected pixel don’t have a significant difference. Hence we can say that this pixel is not at the edge.
#
# ![111.png](data:image/png;base64,...)
#
# ---
#
# Now the question is do we have to sit and manually compare these values to find the edges. Well, obviously not. For the task, we can use a matrix known as the kernel and perform the element-wise multiplication.
#
# ![ker.png](data:image/png;base64,...)
#
# ---
#
# In this example, the result is 354 which is significantly high.  Hence, we can say that the given pixel lies on edge.
#
# ![ker1.png](data:image/png;base64,...)

# %%
# Read the original image
img_BGR = cv2.imread('Couple.jpg')
img_RGB = cv2.cvtColor(img_BGR, cv2.COLOR_BGR2RGB)
plt.imshow(img_RGB)

# %%
# Convert to graycsale
img_gray = cv2.cvtColor(img_BGR, cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray,cmap = 'gray')

# %%
# Blur the image for better edge detection
img_blur = cv2.GaussianBlur(img_gray, (3,3), 0)
plt.imshow(img_blur, cmap='gray')

# %% [markdown]
# # Sobel Edge Detector
#
# ![sober.png](data:image/png;base64,...)

# %%
# Sobel Edge Detection
sobelx = cv2.Sobel(src=img_blur, ddepth=cv2.CV_64F, dx=1, dy=0, ksize=5) # Sobel Edge Detection on the X axis
sobely = cv2.Sobel(src=img_blur, ddepth=cv2.CV_64F, dx=0, dy=1, ksize=5) # Sobel Edge Detection on the Y axis
sobelxy = cv2.Sobel(src=img_blur, ddepth=cv2.CV_64F, dx=1, dy=1, ksize=5) # Combined X and Y Sobel Edge Detection

# %%
# Show the images
plt.figure(figsize=[18,5])
plt.subplot(141);plt.imshow(sobelx,cmap= 'gray');plt.title("sobelx");
plt.subplot(142);plt.imshow(sobely, cmap='gray');plt.title("sobely");
plt.subplot(143);plt.imshow(sobelxy, cmap='gray');plt.title("sobelxy");

# %%
# Perform global thresholding
retval, img_thresh_sobelx= cv2.threshold(sobelx,100, 255, cv2.THRESH_BINARY)
retval, img_thresh_sobely = cv2.threshold(sobely,100, 255, cv2.THRESH_BINARY)
retval, img_thresh_sobelxy = cv2.threshold(sobelxy,100, 255, cv2.THRESH_BINARY)

# %%
plt.figure(figsize=[18,5])
plt.subplot(141);plt.imshow(img_thresh_sobelx,cmap= 'gray');plt.title("img_thresh_sobelx");
plt.subplot(142);plt.imshow(img_thresh_sobely, cmap='gray');plt.title("img_thresh_sobely");
plt.subplot(143);plt.imshow(img_thresh_sobelxy, cmap='gray');plt.title("img_thresh_sobelxy");

# %% [markdown]
# # Canny Edge Detection

# %%
canny_edges = cv2.Canny(image=img_blur, threshold1=130, threshold2=200) # Canny Edge Detection

# %%
plt.imshow(canny_edges,cmap= 'gray');plt.title("canny_edges");

# %% [markdown]
# # Happy Learning
